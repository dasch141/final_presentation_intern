# %% [markdown]
# ![liqomics_logo](images/liqomics_logo.png)
#
# ## About LIQOMICS
#
# * Academic spin-off from Cologne
# * Advancing liquid biopsy technology for tumor diagnostics
# * LymphoVista:
#     * Service to Detect and Monitor Lymphomas and Hematological Cancers
#     * Analysis of blood samples to detect cell-free DNA (cfDNA) and cirulating tumor DNA (ctDNA)
#     * Monitors minimal residual disease (MRD)

# %% [markdown]
# ## Highly sensitive MRD test to monitor cancer progression
#
# <img src="images/mrd.jpg" alt="Figure" width="800" height="600">

# %% [markdown]
# ## cell-free DNA
#
# * degraded small DNA fragments (50 - 200 bp)
#     * cleaved by nucleases
# * released by dead cells
#     * mainly through apoptosis, necrosis, active secretion
# * contain molecular features characteristic of their tissues of origin
#     * fragment size
#     * methylation status
#     * end motifs

# %% [markdown]
# ## Nucleosome, Chromatin structure, and nuclease content influence feature characteristics
#
# ![cell_free_dna](images/cell_free_dna.png)

# %% [markdown]
# ## Projects Overview
#
# 1. Hodgkin Lymphoma
#     * cell-free DNA sequencing data from Hodgkin Lymphoma Patients
#         * data before and after two cycles of chemotherapy
#         * information about relapse
#     * Goal:
#         * Create machine learning model to predict relapse
#     * Result:
#         * not enough samples to create a good predicting model
#
# 2. Solid Tumors (Finale_DB)
#     * cell-free DNA sequencing data from 4 publications
#         * Jiang_2015, Cristiano_2019, Snyder_2016, Sun_2019
#         * over 800 samples in total
#         * healthy and cancer samples
#     * Goal:
#         * Create machine learning model to predict cancer or non-cancer for solid tumors

# %%
from scripts.downsampling_scjs import downsampling_nas
from scripts.visualize_features import create_dfs_for_plotting, calc_chromosome_coverage
from scripts.visualize_normalized_data import ggboxplot_scjs, interactive_plot, import_df_usecols
from scripts.feature_selection_scjs import (high_correlation_mw_filter, selection_tpot_split, del_bin_and_other_features,
                                            selection_tpot_split_stratified, feature_selection, generate_export_tpot_set)
from scripts.features_results_analysis import (extract_acc_and_feat_Importance, filter_max_weighted_classifiers, print_features_count,
                                                            finding_duplicates, top_ten_importance_features, filter_importance_features_tpot)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
from IPython.display import display, HTML
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning)

# %%
# Example DataFrame (replace with your actual data)
samples = pd.read_csv('results/downsampling_scjs_241128_smp_output.csv', usecols=['disease', 'source', 'sample'])

# Group and summarize
full_summary = samples.groupby('source').agg({
    'disease': lambda x: '<br>'.join(sorted(x.unique())),
    'sample': pd.Series.nunique
}).reset_index()

# Rename columns for clarity
full_summary.columns = ['Source', 'Diseases Covered', 'Total Samples']

# Split DataFrame into chunks
chunk_size = 2  # Adjust as needed
chunks = [full_summary[i:i + chunk_size] for i in range(0, len(full_summary), chunk_size)]

# Build HTML for side-by-side display
html_tables = ''.join(
    chunk.style.set_properties(**{
        'white-space': 'pre-wrap',
        'word-wrap': 'break-word'
    }).hide(axis="index").to_html(classes='table table-striped', escape=False)
    for chunk in chunks
)

# Display with CSS for side-by-side layout
html_output = f"""
<div style="display: flex; justify-content: space-around; flex-wrap: wrap;">
{html_tables}
</div>
"""

display(HTML(html_output))
# Out:
# <div style="display: flex; justify-content: space-around; flex-wrap: wrap;">
# <style type="text/css">
# #T_0ed9c_row0_col0, #T_0ed9c_row0_col1, #T_0ed9c_row0_col2, #T_0ed9c_row1_col0, #T_0ed9c_row1_col1, #T_0ed9c_row1_col2 {
#   white-space: pre-wrap;
#   word-wrap: break-word;
# }
# </style>
# <table id="T_0ed9c">
#   <thead>
#     <tr>
#       <th id="T_0ed9c_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_0ed9c_level0_col1" class="col_heading level0 col1" >Diseases Covered</th>
#       <th id="T_0ed9c_level0_col2" class="col_heading level0 col2" >Total Samples</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0ed9c_row0_col0" class="data row0 col0" >Cristiano_2019</td>
#       <td id="T_0ed9c_row0_col1" class="data row0 col1" >Bile_duct_cancer<br>Breast_cancer<br>Colorectal_cancer<br>Duodenal_cancer<br>Gastric_cancer<br>Healthy<br>Lung_cancer<br>Ovarian_cancer<br>Pancreatic_cancer</td>
#       <td id="T_0ed9c_row0_col2" class="data row0 col2" >536</td>
#     </tr>
#     <tr>
#       <td id="T_0ed9c_row1_col0" class="data row1 col0" >Jiang_2015</td>
#       <td id="T_0ed9c_row1_col1" class="data row1 col1" >Cirrhosis<br>Healthy<br>Hepatitis_B<br>Liver_cancer</td>
#       <td id="T_0ed9c_row1_col2" class="data row1 col2" >225</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_08899_row0_col0, #T_08899_row0_col1, #T_08899_row0_col2, #T_08899_row1_col0, #T_08899_row1_col1, #T_08899_row1_col2 {
#   white-space: pre-wrap;
#   word-wrap: break-word;
# }
# </style>
# <table id="T_08899">
#   <thead>
#     <tr>
#       <th id="T_08899_level0_col0" class="col_heading level0 col0" >Source</th>
#       <th id="T_08899_level0_col1" class="col_heading level0 col1" >Diseases Covered</th>
#       <th id="T_08899_level0_col2" class="col_heading level0 col2" >Total Samples</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_08899_row0_col0" class="data row0 col0" >Snyder_2016</td>
#       <td id="T_08899_row0_col1" class="data row0 col1" >Bladder_cancer<br>Breast_cancer<br>Colorectal_cancer<br>Esophageal_cancer<br>Head_and_neck_cancer<br>Healthy<br>Inflammatory_bowel_disease<br>Kidney_cancer<br>Liver_cancer<br>Lung_cancer<br>Ovarian_cancer<br>Pancreatic_cancer<br>Prostate_cancer<br>Skin_cancer<br>Systemic_lupus_erythematosus<br>Testicular_cancer<br>Uterine_cancer</td>
#       <td id="T_08899_row0_col2" class="data row0 col2" >58</td>
#     </tr>
#     <tr>
#       <td id="T_08899_row1_col0" class="data row1 col0" >Sun_2019</td>
#       <td id="T_08899_row1_col1" class="data row1 col1" >Colorectal_cancer<br>Liver_transplant</td>
#       <td id="T_08899_row1_col2" class="data row1 col2" >29</td>
#     </tr>
#   </tbody>
# </table>
#
# </div>

# %% [markdown]
# ## Workflow
#
# 1. Downsampling
#
# 2. Feature Normalization
#
# 3. Feature Selection
#
# 4. Machine learning (TPOT)

# %% [markdown]
# # Finale DB Data - Final Pipeline

# %% [markdown]
# ## Downsampling

# %%
downsampling = False

if downsampling:
    source_list = ['Outputs/Jiang_2015', 'Cristiano_2019', 'Snyder_2016', 'Sun_2019']
    output_downsampling_smp = '/mnt/nas/research/FinaleDB_hg38/blood_plasma/output_downsampling_241128_smp/'
    nas_dir = '/mnt/nas/research/FinaleDB_hg38/blood_plasma/'

    downsampling_nas(source_list, 'smp', nas_dir, output_downsampling_smp, export_files=True)

# Alternativly run script 'downsampling_SCJS_241127.py'

# %%
csv_ds = 'results/downsampling_scjs_241128_smp_output.csv'
csv_cov = 'results/downsampling_scjs_241128_smp_outputCov.csv'
df_plot, df_cov_plot, sorted_order = create_dfs_for_plotting(csv_ds, csv_cov)
df_plot.head(4)
# Out:
# Number of total samples after downsampling: 848
#     sample        disease          source chromosome   strand  n_fragments  \
# 0  EE85754    Hepatitis_B      Jiang_2015       chr1  reverse      1330369
# 1  EE87861  Breast_cancer  Cristiano_2019       chr1  reverse      1088503
# 2  EE87860  Breast_cancer  Cristiano_2019       chr1  reverse      1379473
# 3  EE87859  Breast_cancer  Cristiano_2019       chr1  reverse      1345788
#
#    avg_frag_len  sum_fragments_sample  percent_sample  downsampling_value  \
# 0           170              16925308        7.860235             5553160
# 1           169              13805538        7.884539             5553160
# 2           170              17319462        7.964872             5553160
# 3           166              16903073        7.961795             5553160
#
#    downsampling_to  sum_fragments_downsampled  n_remove  n_remove_percent
# 0           436491                    5553158    893878         67.190230
# 1           437841                    5553161    650662         59.775856
# 2           442302                    5553160    937171         67.936890
# 3           442131                    5553163    903657         67.147060

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=df_plot.loc[df_plot['strand'] == 'reverse'], x='disease', y='sum_fragments_sample', hue='disease', palette='Set2', fliersize=3, order=sorted_order)
plt.title('Total Number of Fragments (reverse strand) per Sample between Diseases')
plt.xticks(rotation=90)
plt.yscale('log')
plt.show()

plt.figure(figsize=(16,8))
dotted_lines = [500, 200, 100, 50, 25]
for i in dotted_lines:
    color = 'red' if i == 25 else 'gray'
    plt.axhline(y=i, color=color, linestyle='--', linewidth=1)
    plt.text(x=22.3, y=i, s=f'{i}%', color=color, va='bottom', ha='right')
sns.boxplot(data=df_cov_plot, x='disease', y='coverage', hue='disease', palette='Set2', order=sorted_order)
plt.title('Sample Coverage per Sample between Diseases (Cutoff at 25%)')
plt.xticks(rotation=90)
plt.yscale('log')
plt.show()

plt.figure(figsize=(16,4))
sns.barplot(data=df_plot.loc[df_plot['strand'] == 'reverse'], x='chromosome', y='downsampling_to', hue='chromosome', palette='Set2')
plt.title('Number of Fragments per Chromosome after Downsampling (Reverse Strand)')
plt.show()

csv_chr_lengths = 'data/chromosome_length_diploid_genome.txt'
frag_chr_rev = calc_chromosome_coverage(df_plot, csv_chr_lengths, 'reverse')

plt.figure(figsize=(16,4))
sns.barplot(data=frag_chr_rev, x='chromosome', y='coverage', hue='chromosome', palette='Set2')
plt.ylim(0,100)
plt.title('Coverage per Chromosome after downsampling (%)')
plt.show()

# %% [markdown]
# ## Feature Normalization

# %%
strands = ['fwd', 'rev']

for strand in strands:
    df = pd.read_csv(f'results/norm_data_scjs_241128_smp_output_5M_{strand}.csv', index_col=0, nrows=5)
    df2 = pd.read_csv(f'results/norm_data_scjs_241128_smp_output2_5M_{strand}.csv', index_col=0, nrows=5)
    print(f'### {strand} ###')
    n_cols1 = df.shape[1]-3 # subtract 'source', 'disease', 'strand'
    n_cols2 = df2.shape[1]-4 # subtract 'source', 'disease', 'target', 'strand'
    print(f'Number of features  after normalization: {n_cols1}') 
    print(f'Number of features after filtering out columns containing empty or inf values: {n_cols2}')
    print(f'Removed features by filtering: {n_cols1 - n_cols2}')
    print()
    del df, df2
# Out:
# ### fwd ###
# Number of features  after normalization: 78090
# Number of features after filtering out columns containing empty or inf values: 76670
# Removed features by filtering: 1420
#
# ### rev ###
# Number of features  after normalization: 78090
# Number of features after filtering out columns containing empty or inf values: 76801
# Removed features by filtering: 1289

# %%
norm_data = 'results/norm_data_scjs_241128_smp_output2_5M_rev.csv'
def import_df_usecols(feature, file_path=norm_data):
    df_cols = pd.read_csv(file_path, index_col=0, nrows=2)
    cols = [col for col in df_cols if col.endswith(feature)] + ['sample', 'source', 'disease', 'target', 'strand']
    df = pd.read_csv(file_path, index_col=0, usecols=cols)
    return df
df = import_df_usecols('med')
df
# Out:
#                  source            disease  target   strand  chr1-P0m-med  \
# sample
# EE85723        Sun_2019  Colorectal_cancer       1  reverse         142.0
# EE85724        Sun_2019  Colorectal_cancer       1  reverse         144.0
# EE85725        Sun_2019   Liver_transplant       0  reverse         169.5
# EE85726        Sun_2019  Colorectal_cancer       1  reverse         145.5
# EE85727        Sun_2019  Colorectal_cancer       1  reverse         142.0
# ...                 ...                ...     ...      ...           ...
# EE88321  Cristiano_2019  Pancreatic_cancer       1  reverse         168.0
# EE88322  Cristiano_2019  Pancreatic_cancer       1  reverse         164.5
# EE88323  Cristiano_2019  Pancreatic_cancer       1  reverse         164.0
# EE88324  Cristiano_2019  Pancreatic_cancer       1  reverse         166.0
# EE88325  Cristiano_2019   Bile_duct_cancer       1  reverse         163.5
#
#          chr1-P100m-med  chr1-P105m-med  chr1-P10m-med  chr1-P110m-med  \
# sample
# EE85723           150.0           148.5          144.5           145.0
# EE85724           151.5           151.5          145.5           148.0
# EE85725           170.5           169.0          169.0           170.5
# EE85726           153.5           152.5          146.0           148.5
# EE85727           151.5           150.5          144.0           147.0
# ...                 ...             ...            ...             ...
# EE88321           167.5           167.5          167.5           167.5
# EE88322           163.5           163.0          163.5           163.5
# EE88323           164.5           164.5          164.0           164.5
# EE88324           166.5           166.0          166.0           166.0
# EE88325           163.0           163.0          163.5           162.5
#
#          chr1-P115m-med  ...  chr9-P40m-med  chr9-P5m-med  chr9-P60m-med  \
# sample                   ...
# EE85723           146.0  ...          127.0         147.0          148.0
# EE85724           148.5  ...          133.5         149.5          151.5
# EE85725           169.5  ...          169.0         169.5          169.0
# EE85726           150.5  ...          133.0         150.5          150.5
# EE85727           147.0  ...          128.5         149.0          150.0
# ...                 ...  ...            ...           ...            ...
# EE88321           167.5  ...          168.0         167.5          168.0
# EE88322           163.5  ...          163.0         163.5          164.5
# EE88323           164.0  ...          164.5         164.0          164.0
# EE88324           167.0  ...          167.0         166.0          166.5
# EE88325           162.0  ...          163.0         162.0          163.5
#
#          chr9-P65m-med  chr9-P70m-med  chr9-P75m-med  chr9-P80m-med  \
# sample
# EE85723          146.5          149.5          146.0          147.0
# EE85724          146.0          150.0          149.0          149.0
# EE85725          170.5          170.0          169.0          170.0
# EE85726          149.0          152.5          149.5          150.5
# EE85727          148.5          150.5          148.5          148.5
# ...                ...            ...            ...            ...
# EE88321          167.5          167.5          168.0          167.0
# EE88322          163.5          163.0          163.0          163.5
# EE88323          164.0          164.0          164.5          164.5
# EE88324          166.0          166.5          166.0          167.0
# EE88325          162.5          162.5          163.0          163.0
#
#          chr9-P85m-med  chr9-P90m-med  chr9-P95m-med
# sample
# EE85723          145.0          145.5          146.0
# EE85724          147.0          148.0          148.0
# EE85725          169.0          169.5          169.5
# EE85726          149.0          149.0          148.0
# EE85727          147.0          148.0          147.0
# ...                ...            ...            ...
# EE88321          167.5          167.0          167.0
# EE88322          163.0          163.0          163.5
# EE88323          164.0          163.5          164.5
# EE88324          166.0          166.5          166.5
# EE88325          163.5          163.5          162.5
#
# [848 rows x 573 columns]

# %% [markdown]
# ### Feature Visualization

# %%
norm_data = 'results/norm_data_scjs_241128_smp_output2_5M_rev.csv'

med_quart_list = ['med', 'TG_166_250_bimers_starts', 'AT_166_250_bimers_ends']
for feature in med_quart_list:
    df = import_df_usecols(feature, norm_data)
    ggboxplot_scjs(df, feature, 'sample', 'reverse')

# %% [markdown]
# ## Feature Selection

# %%
df_5m = pd.read_csv('results/norm_data_scjs_241128_smp_output2_5M_rev.csv', index_col = 0)
df_5m = del_bin_and_other_features(df_5m, ['mode', 'sum', 'std'])

# %%
feat_select_5m2_plus, tpot_5m2_plus = selection_tpot_split_stratified(df_5m)

# selected_features_5m2_plus = feature_selection(feat_select_5m2_plus, 0.7, 0.01)
# selected_features_5m2_plus.to_csv('results/norm_data_scjs_241128_smp_selected_features2plus_rev.csv')

selected_features_5m2_plus = pd.read_csv('results/norm_data_scjs_241128_smp_selected_features2plus_rev.csv', index_col=0)

generate_export_tpot_set(selected_features_5m2_plus, tpot_5m2_plus, 'input_tpot_scjs_241128_smp_5m2_plus')

selected_features_5m2_plus.head(2)
# Out:
# Feature Selection Samples: 42
# Remaining Samples for Model Training: 806
#          chr1-P140m-AC_166_250_bimers_ends  chr1-P145m-CA_166_250_bimers_ends  \
# sample
# EE87914                           0.004662                           0.002667
# EE85729                           0.000000                           0.005612
#
#          chr1-P155m-TA_166_250_bimers_ends  \
# sample
# EE87914                           0.002361
# EE85729                           0.004261
#
#          chr1-P215m-GG_80_165_bimers_starts  chr1-P70m-GT_bimers_starts  \
# sample
# EE87914                            0.002032                    0.061149
# EE85729                            0.001777                    0.025653
#
#          chr1-P90m-bimers_end_80_165_mds  chr10-P20m-CG_166_250_bimers_ends  \
# sample
# EE87914                         0.732766                           0.000490
# EE85729                         0.720809                           0.001251
#
#          chr11-P130m-AT_166_250_bimers_starts  chr11-P25m-CGN_NCG_ratios  \
# sample
# EE87914                              0.002611                   1.368421
# EE85729                              0.001136                   1.075000
#
#          chr11-P35m-bimers_start_80_165_mds  ...  \
# sample                                       ...
# EE87914                            0.727566  ...
# EE85729                            0.721542  ...
#
#          chr7-P65m-AC_166_250_bimers_ends  chr7-P65m-GT_166_250_bimers_starts  \
# sample
# EE87914                          0.003424                            0.003203
# EE85729                          0.001052                            0.001052
#
#          chr8-P115m-CG_166_250_bimers_starts  \
# sample
# EE87914                             0.000374
# EE85729                             0.000383
#
#          chr8-P125m-bimers_end_80_165_mds  chr8-P40m-AG_bimers_ends  \
# sample
# EE87914                          0.734192                  0.077093
# EE85729                          0.714684                  0.070532
#
#          chr9-P100m-AA_166_250_bimers_ends  chr9-P125m-CT_bimers_starts  \
# sample
# EE87914                           0.002699                     0.076003
# EE85729                           0.001659                     0.070795
#
#          chr9-P30m-CGN_NCG_ratios  chr9-P60m-CG_bimers_ends  \
# sample
# EE87914                  1.838710                  0.008621
# EE85729                  1.059701                  0.018830
#
#          chr9-P65m-AG_166_250_bimers_starts
# sample
# EE87914                            0.001907
# EE85729                            0.003297
#
# [2 rows x 78 columns]

# %% [markdown]
# ## TPOT

# %% [markdown]
# ### Classifier Performance on Training Data

# %%
df_class = pd.read_csv('results/tpot_best_of/results1/1-input_tpot_scjs_241128_smp_5m2_plus/classifiers/input_tpot_scjs_241128_smp_5m2_plus-classifiers_results_mean.csv', index_col=0)

df = df_class.reset_index()
idx = df.groupby('Classifier')['Weighted_Score'].idxmax()

filtered_df = df[df.index.isin(idx)].drop(columns=['Unnamed: 0', 'Hyperparameter_Count.1', 'Fold_ID']).style.set_caption("Table: Best Classifiers after training")
filtered_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fcb2">
#   <caption>Table: Best Classifiers after training</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fcb2_level0_col0" class="col_heading level0 col0" >Classifier</th>
#       <th id="T_1fcb2_level0_col1" class="col_heading level0 col1" >Hyperparameter_Count</th>
#       <th id="T_1fcb2_level0_col2" class="col_heading level0 col2" >Accuracy</th>
#       <th id="T_1fcb2_level0_col3" class="col_heading level0 col3" >Sensitivity</th>
#       <th id="T_1fcb2_level0_col4" class="col_heading level0 col4" >Specificity</th>
#       <th id="T_1fcb2_level0_col5" class="col_heading level0 col5" >Weighted_Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fcb2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1fcb2_row0_col0" class="data row0 col0" >BernoulliNB</td>
#       <td id="T_1fcb2_row0_col1" class="data row0 col1" >475</td>
#       <td id="T_1fcb2_row0_col2" class="data row0 col2" >0.581818</td>
#       <td id="T_1fcb2_row0_col3" class="data row0 col3" >0.240984</td>
#       <td id="T_1fcb2_row0_col4" class="data row0 col4" >0.928333</td>
#       <td id="T_1fcb2_row0_col5" class="data row0 col5" >0.652825</td>
#     </tr>
#     <tr>
#       <th id="T_1fcb2_level0_row1" class="row_heading level0 row1" >8</th>
#       <td id="T_1fcb2_row1_col0" class="data row1 col0" >ExtraTreesClassifier</td>
#       <td id="T_1fcb2_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_1fcb2_row1_col2" class="data row1 col2" >0.788430</td>
#       <td id="T_1fcb2_row1_col3" class="data row1 col3" >0.660656</td>
#       <td id="T_1fcb2_row1_col4" class="data row1 col4" >0.918333</td>
#       <td id="T_1fcb2_row1_col5" class="data row1 col5" >0.815049</td>
#     </tr>
#     <tr>
#       <th id="T_1fcb2_level0_row2" class="row_heading level0 row2" >138</th>
#       <td id="T_1fcb2_row2_col0" class="data row2 col0" >RandomForestClassifier</td>
#       <td id="T_1fcb2_row2_col1" class="data row2 col1" >228</td>
#       <td id="T_1fcb2_row2_col2" class="data row2 col2" >0.814876</td>
#       <td id="T_1fcb2_row2_col3" class="data row2 col3" >0.762295</td>
#       <td id="T_1fcb2_row2_col4" class="data row2 col4" >0.868333</td>
#       <td id="T_1fcb2_row2_col5" class="data row2 col5" >0.825830</td>
#     </tr>
#     <tr>
#       <th id="T_1fcb2_level0_row3" class="row_heading level0 row3" >266</th>
#       <td id="T_1fcb2_row3_col0" class="data row3 col0" >XGBClassifier</td>
#       <td id="T_1fcb2_row3_col1" class="data row3 col1" >459</td>
#       <td id="T_1fcb2_row3_col2" class="data row3 col2" >0.806612</td>
#       <td id="T_1fcb2_row3_col3" class="data row3 col3" >0.798361</td>
#       <td id="T_1fcb2_row3_col4" class="data row3 col4" >0.815000</td>
#       <td id="T_1fcb2_row3_col5" class="data row3 col5" >0.808331</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Selected Classifiers for Final Classifier Train Set

# %%
df_blind_class = pd.DataFrame(df.loc[(df['Accuracy'] > 0.7) & (df['Sensitivity'] > 0.7) & (df['Specificity'] > 0.8)]
                  .groupby('Classifier')['Hyperparameter_Count'].count()).rename(columns={'Hyperparameter_Count': 'Count'})
df_blind_class
# Out:
#                         Count
# Classifier
# RandomForestClassifier    151
# XGBClassifier               8

# %% [markdown]
# ### Feature Importance for Training Data

# %%
randomforest = '/home/david/Projects/Finale_DB/results/tpot_best_of/results1/1-input_tpot_scjs_241128_smp_5m2_plus/classifiers/input_tpot_scjs_241128_smp_5m2_plus_RandomForestClassifier-classifier_feature_importance.csv'
xgb = '/home/david/Projects/Finale_DB/results/tpot_best_of/results1/1-input_tpot_scjs_241128_smp_5m2_plus/classifiers/input_tpot_scjs_241128_smp_5m2_plus_XGBClassifier-classifier_feature_importance.csv'
dict_classifier = {randomforest: 228, xgb: 459}

df_importance_train = filter_importance_features_tpot(dict_classifier)
dfi_train, dfiRanked_train = top_ten_importance_features(df_importance_train)
display(dfi_train.head(10))
display(dfiRanked_train)
# Out:
#                                Feature  RandomForestClassifier_228  \
# 0                  chr15-P60m-coverage                    0.039722
# 1                   chr20-P5m-coverage                    0.035050
# 2          chr9-P125m-CT_bimers_starts                    0.029529
# 3             chr5-P65m-AG_bimers_ends                    0.028884
# 4             chr8-P40m-AG_bimers_ends                    0.027697
# 5                  chr5-P140m-coverage                    0.026865
# 6            chr5-P100m-AG_bimers_ends                    0.026772
# 7  chr13-P95m-AG_166_250_bimers_starts                    0.026503
# 8  chr12-P70m-AG_166_250_bimers_starts                    0.025008
# 9            chr4-P180m-AG_bimers_ends                    0.024981
#
#                                Feature  XGBClassifier_459
# 0                  chr15-P60m-coverage           0.046827
# 1             chr5-P65m-AG_bimers_ends           0.042846
# 2            chr4-P180m-AG_bimers_ends           0.042642
# 3          chr9-P125m-CT_bimers_starts           0.029304
# 4            chr5-P100m-AG_bimers_ends           0.026779
# 5                   chr20-P5m-coverage           0.025904
# 6           chr3-P90m-bimers_start_mds           0.022920
# 7             chr8-P40m-AG_bimers_ends           0.021738
# 8  chr13-P95m-AG_166_250_bimers_starts           0.021229
# 9    chr2-P0m-TC_166_250_bimers_starts           0.020504
#                                      RandomForestClassifier_228  \
# Feature
# chr15-P60m-coverage                                           1
# chr20-P5m-coverage                                            2
# chr9-P125m-CT_bimers_starts                                   3
# chr5-P65m-AG_bimers_ends                                      4
# chr8-P40m-AG_bimers_ends                                      5
# chr5-P100m-AG_bimers_ends                                     7
# chr13-P95m-AG_166_250_bimers_starts                           8
# chr4-P180m-AG_bimers_ends                                    10
#
#                                      XGBClassifier_459
# Feature
# chr15-P60m-coverage                                  1
# chr20-P5m-coverage                                   6
# chr9-P125m-CT_bimers_starts                          4
# chr5-P65m-AG_bimers_ends                             2
# chr8-P40m-AG_bimers_ends                             8
# chr5-P100m-AG_bimers_ends                            5
# chr13-P95m-AG_166_250_bimers_starts                  9
# chr4-P180m-AG_bimers_ends                            3

# %% [markdown]
# ### Classifier Performance on Blind Test Set

# %%
df_acc = pd.read_csv('results/tpot_best_of/results1/1-input_tpot_scjs_241128_smp_5m2_plus/final_classifiers/input_tpot_scjs_241128_smp_5m2_plus-final_classifiers_blind_test_results.csv')
df_acc.rename(columns={'Unnamed: 0': 'Classifier'}, inplace=True)

list_classifiers1 = ['RandomForestClassifier_228', 'XGBClassifier_459', 'BernoulliNB_475', 'ExtraTreesClassifier_55']
display(df_acc.loc[df_acc['Classifier'].isin(list_classifiers1)])

display(df_acc.sort_values('Weighted_Score').head(2))
# Out:
#                      Classifier  Accuracy  Sensitivity  Specificity  \
# 101  RandomForestClassifier_228       1.0          1.0          1.0
# 161           XGBClassifier_459       1.0          1.0          1.0
#
#         Confusion_Matrix  Weighted_Score
# 101  [[81  0]\n [ 0 81]]             1.0
# 161  [[81  0]\n [ 0 81]]             1.0
#                      Classifier  Accuracy  Sensitivity  Specificity  \
# 95   RandomForestClassifier_198  0.882716     0.814815     0.950617
# 154           XGBClassifier_359  0.888889     0.827160     0.950617
#
#         Confusion_Matrix  Weighted_Score
# 95   [[77  4]\n [15 66]]        0.896296
# 154  [[77  4]\n [14 67]]        0.901235

# %%
df_importance = pd.read_csv('results/tpot_best_of/results1/1-input_tpot_scjs_241128_smp_5m2_plus/final_classifiers/input_tpot_scjs_241128_smp_5m2_plus-final_classifiers_feature_importance.csv', index_col=0)
df_importance = df_importance[[col for col in df_importance.columns if col.removeprefix('Importance_') in list_classifiers1]]

dfi, dfiRanked = top_ten_importance_features(df_importance)
display(dfi.head(10))
display(dfiRanked)
# Out:
#                              Feature  Importance_RandomForestClassifier_228  \
# 0                chr15-P60m-coverage                               0.038427
# 1                 chr20-P5m-coverage                               0.036640
# 2        chr9-P125m-CT_bimers_starts                               0.035704
# 3           chr8-P40m-AG_bimers_ends                               0.032551
# 4          chr4-P180m-AG_bimers_ends                               0.028668
# 5                chr5-P140m-coverage                               0.026348
# 6          chr5-P100m-AG_bimers_ends                               0.026063
# 7         chr3-P90m-bimers_start_mds                               0.025871
# 8  chr20-P35m-GA_166_250_bimers_ends                               0.025727
# 9           chr5-P65m-AG_bimers_ends                               0.024950
#
#                                Feature  Importance_XGBClassifier_459
# 0                  chr15-P60m-coverage                      0.055340
# 1             chr8-P40m-AG_bimers_ends                      0.054111
# 2             chr5-P65m-AG_bimers_ends                      0.052793
# 3          chr9-P125m-CT_bimers_starts                      0.032789
# 4            chr4-P180m-AG_bimers_ends                      0.026407
# 5    chr4-P50m-GT_80_165_bimers_starts                      0.024639
# 6                   chr20-P5m-coverage                      0.021794
# 7  chr12-P70m-AG_166_250_bimers_starts                      0.021741
# 8           chr3-P90m-bimers_start_mds                      0.021711
# 9     chr14-P60m-TC_80_165_bimers_ends                      0.021705
#                              Importance_RandomForestClassifier_228  \
# Feature
# chr15-P60m-coverage                                              1
# chr20-P5m-coverage                                               2
# chr9-P125m-CT_bimers_starts                                      3
# chr8-P40m-AG_bimers_ends                                         4
# chr4-P180m-AG_bimers_ends                                        5
# chr3-P90m-bimers_start_mds                                       8
# chr5-P65m-AG_bimers_ends                                        10
#
#                              Importance_XGBClassifier_459
# Feature
# chr15-P60m-coverage                                     1
# chr20-P5m-coverage                                      7
# chr9-P125m-CT_bimers_starts                             4
# chr8-P40m-AG_bimers_ends                                2
# chr4-P180m-AG_bimers_ends                               5
# chr3-P90m-bimers_start_mds                              9
# chr5-P65m-AG_bimers_ends                                3

# %% [markdown]
# ### Compare Feature Importance of Training and Blind Test Set

# %%
dfiRanked_all = (
    pd.merge(dfiRanked_train, dfiRanked, on='Feature', how='outer')
    .fillna(0)
    .astype('int64', errors='ignore')
    .replace(0, '-')
    .rename(columns=lambda col: col.replace('Importance', 'Blind_Testing'))
)
display(dfiRanked_all)
# Out:
#                                     RandomForestClassifier_228  \
# Feature
# chr13-P95m-AG_166_250_bimers_starts                          8
# chr15-P60m-coverage                                          1
# chr20-P5m-coverage                                           2
# chr3-P90m-bimers_start_mds                                   -
# chr4-P180m-AG_bimers_ends                                   10
# chr5-P100m-AG_bimers_ends                                    7
# chr5-P65m-AG_bimers_ends                                     4
# chr8-P40m-AG_bimers_ends                                     5
# chr9-P125m-CT_bimers_starts                                  3
#
#                                     XGBClassifier_459  \
# Feature
# chr13-P95m-AG_166_250_bimers_starts                 9
# chr15-P60m-coverage                                 1
# chr20-P5m-coverage                                  6
# chr3-P90m-bimers_start_mds                          -
# chr4-P180m-AG_bimers_ends                           3
# chr5-P100m-AG_bimers_ends                           5
# chr5-P65m-AG_bimers_ends                            2
# chr8-P40m-AG_bimers_ends                            8
# chr9-P125m-CT_bimers_starts                         4
#
#                                     Blind_Testing_RandomForestClassifier_228  \
# Feature
# chr13-P95m-AG_166_250_bimers_starts                                        -
# chr15-P60m-coverage                                                        1
# chr20-P5m-coverage                                                         2
# chr3-P90m-bimers_start_mds                                                 8
# chr4-P180m-AG_bimers_ends                                                  5
# chr5-P100m-AG_bimers_ends                                                  -
# chr5-P65m-AG_bimers_ends                                                  10
# chr8-P40m-AG_bimers_ends                                                   4
# chr9-P125m-CT_bimers_starts                                                3
#
#                                     Blind_Testing_XGBClassifier_459
# Feature
# chr13-P95m-AG_166_250_bimers_starts                               -
# chr15-P60m-coverage                                               1
# chr20-P5m-coverage                                                7
# chr3-P90m-bimers_start_mds                                        9
# chr4-P180m-AG_bimers_ends                                         5
# chr5-P100m-AG_bimers_ends                                         -
# chr5-P65m-AG_bimers_ends                                          3
# chr8-P40m-AG_bimers_ends                                          2
# chr9-P125m-CT_bimers_starts                                       4

# %%
feature_index_list = dfiRanked_all.index.tolist() + ['target']
top_features = df_5m[feature_index_list].copy()

# Ensure correct feature selection
feature_index_list = dfiRanked_all.index.tolist() + ['target']

# Extract selected features from the DataFrame
top_features = df_5m[feature_index_list].copy()  # Avoid chained assignment warnings

# Create a temporary column and rename back to 'target'
top_features['target_temp'] = top_features['target'].map({0: 'non-cancer', 1: 'cancer'}).astype('category')

# Drop the original target column and rename the temp column
top_features.drop('target', axis=1, inplace=True)
top_features.rename(columns={'target_temp': 'target'}, inplace=True)

# Normalize feature columns by dividing by their means
top_features_normalized = top_features.iloc[:, :-1].div(top_features.iloc[:, :-1].mean(), axis=1)

# Add back the 'target' column
top_features_normalized['target'] = top_features['target']

# Display the first few rows
top_features_normalized.head()

def melt_feature_df(df):
    df_melted = df.reset_index().rename(columns={'index': 'sample'}).melt(
    id_vars=['sample', 'target'], var_name='feature', value_name='value')    
    return df_melted

top_features_norm_melted = melt_feature_df(top_features_normalized)
top_features_melted = melt_feature_df(top_features)

# %%
# Try using a boxplot for better visualization
plt.figure(figsize=(14, 8))
sns.boxplot(data=top_features_norm_melted, x='feature', y='value', hue='target', palette='Set2', hue_order=['non-cancer', 'cancer'])
plt.xticks(rotation=45, ha='right')
#plt.yscale('log')
plt.title("Boxplot of Feature Values by Target")
plt.tight_layout()
plt.show()

# %%
# Correct the FacetGrid mapping with adjusted boxplot settings
g = sns.FacetGrid(top_features_melted, col="feature", col_wrap=5, sharey=False, height=4)
# Use a custom function to map boxplots without passing unexpected arguments
def boxplot(data, **kwargs):
    sns.boxplot(x='target', y='value', data=data, hue='target', palette='Set2', order=['non-cancer', 'cancer'])
# Map the corrected boxplot function onto the grid
g.map_dataframe(boxplot)
# Remove 'feature=' from titles
g.set_titles('{col_name}')
# Add a legend
g.add_legend()
# Show the plot
plt.show()
